# %%
import pandas as pd
from statsbombpy import sb
from mplsoccer import Pitch

# %%
sb.competitions()
# Out:
#     competition_id  season_id   country_name        competition_name  \
# 0                9        281        Germany           1. Bundesliga
# 1                9         27        Germany           1. Bundesliga
# 2             1267        107         Africa  African Cup of Nations
# 3               16          4         Europe        Champions League
# 4               16          1         Europe        Champions League
# ..             ...        ...            ...                     ...
# 69              55         43         Europe               UEFA Euro
# 70              35         75         Europe      UEFA Europa League
# 71              53        106         Europe       UEFA Women's Euro
# 72              72        107  International       Women's World Cup
# 73              72         30  International       Women's World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 0                male              False                      False
# ...

# %%
from itscalledsoccer.client import AmericanSoccerAnalysis

asa_client = AmericanSoccerAnalysis()

# %%
asa_client.get_teams(leagues="mls")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/itscalledsoccer/client.py:303: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   resp_df = read_json(json.dumps(response.json()))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/itscalledsoccer/client.py:303: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   resp_df = read_json(json.dumps(response.json()))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/itscalledsoccer/client.py:303: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
# ...

# %%
df_austin_fc = asa_client.get_games(team_names="Austin FC", seasons="2024")
print(df_austin_fc)
# Out:
#        game_id            date_time_utc  home_score  away_score home_team_id  \
# 0   0x5gzY9PM7  2024-07-21 00:30:00 UTC           2           2   gpMOLwl5zy
# 1   KAqBoZ3JQb  2024-07-18 00:30:00 UTC           3           1   mKAqBBmqbg
# 2   xW5pJNWlQg  2024-07-14 00:30:00 UTC           0           1   gpMOLwl5zy
# 3   gjMNr2VvMK  2024-07-07 01:55:00 UTC           2           1   gpMOLwl5zy
# 4   ljqEkvWEMx  2024-06-30 00:30:00 UTC           2           0   Z2vQ1xlqrA
# 5   ljqEkvZzMx  2024-06-23 00:30:00 UTC           0           1   kRQand1MKZ
# 6   vzqozyAj5a  2024-06-20 00:30:00 UTC           1           1   gpMOLwl5zy
# 7   Oa5w6NpjM1  2024-06-16 01:30:00 UTC           2           0   pzeQZ6xQKw
# 8   XVqK7rPOq0  2024-06-02 01:30:00 UTC           5           1   a2lqR4JMr0
# 9   2vQ11JzKQr  2024-05-30 00:30:00 UTC           0           2   gpMOLwl5zy
# 10  315VzAa959  2024-05-26 02:30:00 UTC           1           1   0KPqjA456v
# ...

# %%
asa_client.get_game_xgoals(game_id="0x5gzY9PM7")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/itscalledsoccer/client.py:303: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   resp_df = read_json(json.dumps(response.json()))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/itscalledsoccer/client.py:303: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   resp_df = read_json(json.dumps(response.json()))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/itscalledsoccer/client.py:303: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
# ...

# %%
players = asa_client.get_players()
print(players)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/itscalledsoccer/client.py:303: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   resp_df = read_json(json.dumps(response.json()))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/itscalledsoccer/client.py:303: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   resp_df = read_json(json.dumps(response.json()))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/itscalledsoccer/client.py:303: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
# ...

# %%
austin_players_goals_added = asa_client.get_player_goals_added(team_ids="gpMOLwl5zy")
print(austin_players_goals_added)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/itscalledsoccer/client.py:303: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   resp_df = read_json(json.dumps(response.json()))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/itscalledsoccer/client.py:303: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   resp_df = read_json(json.dumps(response.json()))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/itscalledsoccer/client.py:303: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
# ...

# %%
austin_player_ids = austin_players_goals_added['player_id']
print(austin_player_ids)
# Out:
# 0     0Oq67EgQ6D
# 1     0Oq6lLZgM6
# 2     2lqRJeA4qr
# 3     2vQ1dVlLqr
# 4     2vQ1NO0OMr
# 5     315V7zn7q9
# 6     315VXPJEQ9
# 7     4JMAaoa7MK
# 8     4JMAolz1qK
# 9     4wM4J8bNqj
# 10    7vQ7BardqD
# 11    7VqGjBpz5v
# 12    7VqGjPKj5v
# 13    9vQ2dZE15K
# 14    9YqdogzE5v
# 15    BLMvzPNlMx
# 16    EGMPlpRxMa
# 17    eV5DzmNmQK
# 18    eV5Dzr7EQK
# 19    eVq3alzDMW
# 20    eVq3xk1VQW
# 21    gOMn66nAMw
# 22    gOMnR6e6Mw
# 23    gpMOaDWrqz
# 24    gpMOz1KyQz
# 25    gpMOzKV7Qz
# 26    KXMekOprq6
# 27    KXMeOaaPq6
# 28    ljqE2ekNQx
# 29    ljqE2PwVQx
# 30    ljqEjLaEQx
# 31    N6MmepZxME
# 32    NPqxm7JXQ9
# 33    NWMWVR6jQl
# 34    NWMWXylK5l
# 35    Oa5wVLWAM1
# 36    Oa5wVojBM1
# 37    Oa5wVwxXM1
# 38    Oa5wVzD9M1
# 39    p6qb0L4M0G
# 40    p6qbenoB50
# 41    raMyA6KRMd
# 42    raMyAn8AMd
# 43    wvq9bOBQWn
# 44    wvq9epE3qW
# 45    Xj5Y6AlAqb
# 46    Xj5Y9bmX5b
# 47    Xj5Y9eBx5b
# 48    xW5pynPBqg
# 49    zeQZzPgQKw
# Name: player_id, dtype: object

# %%
# Loop through each player ID to fetch data
for current_id in austin_player_ids:
    # Fetch player data
    player_data = asa_client.get_players(ids=current_id)
    print(player_data['player_name'])
# Out:
# 918    Matt Besler
# Name: player_name, dtype: object
# 941    Maximiliano Urruti
# Name: player_name, dtype: object
# 1076    Bryant Farkarlun
# 8858    Bryant Farkarlun
# Name: player_name, dtype: object
# 1166    Alonso Jiménez
# 8921    Alonso Jiménez
# Name: player_name, dtype: object
# 1193    Jáder Obrian
# Name: player_name, dtype: object
# 1205    Sofiane Djeffal
# 4203    Sofiane Djeffal
# Name: player_name, dtype: object
# 1253    Julio Cascante
# 4263    Julio Cascante
# Name: player_name, dtype: object
# 1286    Héctor Jiménez
# Name: player_name, dtype: object
# 1307    Daniel Pereira Gil
# Name: player_name, dtype: object
# 1354    Owen Wolff
# 4383    Owen Wolff
# Name: player_name, dtype: object
# 1396    Frederik Kleemann
# 4432    Frederik Kleemann
# Name: player_name, dtype: object
# 1489    Jared Stroud
# 4520    Jared Stroud
# Name: player_name, dtype: object
# 1498    Jhohan Romaña
# Name: player_name, dtype: object
# 1570    Will Bruin
# 4607    Will Bruin
# ...

# %% [markdown]
# Mikkel Desler - 2069

# %%
asa_client.get_player_goals_added(player_ids=2069)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
